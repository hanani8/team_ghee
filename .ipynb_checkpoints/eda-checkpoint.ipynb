# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
PATH = "./data.csv"
data = pd.read_csv(PATH)
data.head()
# Out:
#    product_id                                      product_title  \
# 0           1             Garlic Oil - Vegetarian Capsule 500 mg
# 1           2                              Water Bottle - Orange
# 2           3                     Brass Angle Deep - Plain, No.2
# 3           4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4           5                 Creme Soft Soap - For Hands & Body
#
#                  category    product_subcategory              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    selling_price  original_price              product_type  product_rating  \
# 0          220.0           220.0          Hair Oil & Serum             4.1
# ...

# %%
data[(data['product_type'] == "Hair Oil & Serum") & (data['brand'] == "Mamaearth")]
# Out:
#        product_id                                      product_title  \
# 5202         5203  BhringAmla Hair Oil + Shampoo With Bhringraj &...
# 6494         6495  Onion Hair Oil For Hair Regrowth & Hair Fall C...
# 9431         9432  100% Pure Castor Oil, Cold Pressed, To Support...
# 9669         9670  Onion Hair Oil For Regrowth & Hair Fall Contro...
# 10788       10789                                  Anti Hairfall Kit
# 10851       10852                                   Root Restore Oil
# 10914       10915                  Hair Oil - Nourishing, for Babies
# 12448       12449                                Hair Regrowth Tonic
# 13163       13164  Onion Hair Serum For Silky & Smooth Hair - Wit...
# 22709       22710  BhringAmla Hair Oil With Bhringraj & Amla For ...
#
#                category product_subcategory      brand  selling_price  \
# 5202   Beauty & Hygiene           Hair Care  Mamaearth          848.0
# ...

# %%
data[data['product_id'] == 6495].iloc[0]
# Out:
# product_id                                                             6495
# product_title             Onion Hair Oil For Hair Regrowth & Hair Fall C...
# category                                                   Beauty & Hygiene
# product_subcategory                                               Hair Care
# brand                                                             Mamaearth
# selling_price                                                         599.0
# original_price                                                        599.0
# product_type                                               Hair Oil & Serum
# product_rating                                                          4.3
# product_description       Stress, pollution & unhealthy lifestyle choice...
# availability_status                                                In Stock
# customer_reviews_count                                                   69
# ...
