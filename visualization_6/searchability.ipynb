# %%
# !pip3 install spacy
# !python3 -m spacy download en_core_web_lg
# !pip3 install yake
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yake in /home/hegemon/.local/lib/python3.10/site-packages (0.4.8)
# Requirement already satisfied: networkx in /home/hegemon/.local/lib/python3.10/site-packages (from yake) (2.8.8)
# Requirement already satisfied: click>=6.0 in /usr/lib/python3/dist-packages (from yake) (8.0.3)
# Requirement already satisfied: jellyfish in /home/hegemon/.local/lib/python3.10/site-packages (from yake) (1.0.3)
# Requirement already satisfied: numpy in /home/hegemon/.local/lib/python3.10/site-packages (from yake) (1.24.1)
# Requirement already satisfied: segtok in /home/hegemon/.local/lib/python3.10/site-packages (from yake) (1.5.11)
# Requirement already satisfied: tabulate in /home/hegemon/.local/lib/python3.10/site-packages (from yake) (0.9.0)
# Requirement already satisfied: regex in /home/hegemon/.local/lib/python3.10/site-packages (from segtok->yake) (2024.4.16)

# %%
import spacy
import numpy as np
import pandas as pd
import yake
import matplotlib.pyplot as plt

# %%
PATH = "./data.csv"
data = pd.read_csv(PATH)
data.head()
data = data.dropna()

# %%
language = "en"
max_ngram_size = 1
deduplication_threshold = 0.9
deduplication_algo = 'seqm'
windowSize = 1
numOfKeywords = 20
kw_extractor = yake.KeywordExtractor(lan=language, n=1, dedupLim=0.9, dedupFunc='seqm', windowsSize=1)

for index, row in data.iterrows():
    keywords = kw_extractor.extract_keywords(row['product_title'])
    searchability_score = (0.1 * len(keywords)) + 0.9 * np.mean([1 - kw[1] for kw in keywords])
    data.at[index, 'searchability'] = searchability_score
# Out:
# /home/hegemon/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/hegemon/.local/lib/python3.10/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
data = data.sort_values(by='searchability', ascending=False)
data['searchability'] = data['searchability'] / data['searchability'].max()

# %%
data[data['searchability'] > 0.9]
# Out:
#        product_id                                      product_title  \
# 15918       15919  Sanitizer Spray - Air & Surface Disinfectant, ...
# 12864       12865  Biodegradable Super Soft Black Sanitary Napkin...
# 17556       17557  Gift Box - Assorted Nut & Seed Butters, Dairy ...
# 3140         3141  Post Hair Removal Soother - BIO Chlorophyll, O...
# 20893       20894  Germ Protection Fruit & Veggie Wash – Natural ...
# 13355       13356  Biodegradable Super Soft Black Sanitary Napkin...
# 13468       13469  Doraemon Polycarbonate Sports Plastic Sipper B...
# 14863       14864  Melts Whole Grain Snack - Carrot & Cumin, Appl...
# 3791         3792  Chai/Tea/coffee Cup Bonechina & Saucer - White...
# 25981       25982  Anti-bacterial Skin Wipes - Kills 99.9% Germs ...
# 21577       21578  Deltoid Lite Face Masks In Royal Blue, Grey & ...
# 24624       24625  Deltoid Lite Face Masks In Royal Blue, Grey & ...
# 20417       20418  Body Wash Luminous Oils Rejuvenating Shower Ge...
# 11335       11336  Chota Bheem Hot & Cold Large Plastic Lunch Box...
#
#                      category     product_subcategory           brand  \
# 15918        Beauty & Hygiene        Bath & Hand Wash      Godrej Aer
# 12864        Beauty & Hygiene        Feminine Hygiene          Sirona
# 17556    Gourmet & World Food  Sauces, Spreads & Dips      Jus Amazin
# 3140         Beauty & Hygiene        Feminine Hygiene        BIOTIQUE
# 20893    Cleaning & Household    All Purpose Cleaners  Godrej Protekt
# 13355        Beauty & Hygiene        Feminine Hygiene          Sirona
# 13468  Kitchen, Garden & Pets   Storage & Accessories    Yellow Spark
# 14863               Baby Care     Baby Food & Formula          Timios
# 3791   Kitchen, Garden & Pets      Crockery & Cutlery       BP Bharat
# 25981        Beauty & Hygiene               Skin Care  Godrej Protekt
# 21577        Beauty & Hygiene       Health & Medicine             3BO
# 24624        Beauty & Hygiene       Health & Medicine             3BO
# 20417        Beauty & Hygiene        Bath & Hand Wash       Palmolive
# 11335  Kitchen, Garden & Pets   Storage & Accessories    Yellow Spark
#
#        selling_price  original_price                   product_type  \
# 15918         199.00           199.0         Hand Wash & Sanitizers
# 12864         226.59           249.0               Sanitary Napkins
# 17556         399.00           500.0       Chocolate, Peanut Spread
# 3140          149.25           199.0                   Hair Removal
# 20893         199.20           249.0  Disinfectant Spray & Cleaners
# 13355         235.69           259.0               Sanitary Napkins
# 13468         299.00           349.0         Water & Fridge Bottles
# 14863         475.00           475.0                      Baby Food
# 3791          689.00           979.0          Cups, Mugs & Tumblers
# 25981         102.00           120.0                      Face Care
# 21577         490.00           490.0      Face Masks & Safety Gears
# 24624         490.00           490.0      Face Masks & Safety Gears
# 20417         359.40           599.0         Shower Gel & Body Wash
# 11335         289.00           330.0                    Lunch Boxes
#
#        product_rating                                product_description  \
# 15918             3.9  Godrej aer Air & Surface Sanitizer Spray is a ...
# 12864             1.0  Who am I? I am Sirona's Black Pad. I am made w...
# 17556             3.2  This assorted nut and seed butter gift box is ...
# 3140              4.4  This refreshing, anti-baterial moisturizer is ...
# 20893             4.0  Godrej Protekt Germ Protection Fruit & Veggie ...
# 13355             4.4  Who am I? I am Sirona's Black Pad. I am made w...
# 13468             3.0  This bottle comes with ABS plastic top cover w...
# 14863             4.0  Timios Melts snacks are delicious whole grain ...
# 3791              2.0  Enjoy your favourite beverages in this beautif...
# 25981             4.1  Godrej Protekt Anti-bacterial Skin Wipes kills...
# 21577             1.8  Introducing the 3bO Deltoid lite face mask tha...
# 24624             2.0  Introducing the 3bO Deltoid lite face mask tha...
# 20417             4.2  * Infused with 100% natural Fig Oil and White ...
# 11335             4.0  This Lunch Box is made with food-grade quality...
#
#       availability_status  customer_reviews_count seasonal_indicator  \
# 15918            In Stock                      21             Summer
# 12864            In Stock                      88             Winter
# 17556            In Stock                      23             Summer
# 3140             In Stock                      61             Spring
# 20893            In Stock                      81             Winter
# 13355            In Stock                      10             Autumn
# 13468            In Stock                       4             Autumn
# 14863            In Stock                      63             Winter
# 3791             In Stock                      95             Autumn
# 25981            In Stock                      73             Spring
# 21577            In Stock                       8             Winter
# 24624            In Stock                      31             Spring
# 20417            In Stock                      34             Autumn
# 11335            In Stock                      19             Autumn
#
#       promotion_indicator  shipping_weight bundle_indicator  \
# 15918                  No         3.407798       Individual
# 12864                 Yes         0.592459       Individual
# 17556                  No         2.149013           Bundle
# 3140                  Yes         4.961404       Individual
# 20893                 Yes         3.088472           Bundle
# 13355                  No         1.335912           Bundle
# 13468                  No         4.475749           Bundle
# 14863                 Yes         0.648293           Bundle
# 3791                   No         4.596700           Bundle
# 25981                  No         0.501066           Bundle
# 21577                 Yes         1.124617       Individual
# 24624                  No         0.696380       Individual
# 20417                  No         4.506110           Bundle
# 11335                  No         3.251991       Individual
#
#       customer_demographics  searchability
# 15918                Female       1.000000
# 12864                 Other       0.996867
# 17556                Female       0.970137
# 3140                 Female       0.966147
# 20893                Female       0.965543
# 13355                Female       0.953189
# 13468                 Other       0.946836
# 14863                Female       0.926448
# 3791                  Other       0.925666
# 25981                  Male       0.925166
# 21577                Female       0.922471
# 24624                Female       0.922471
# 20417                Female       0.915295
# 11335                Female       0.911198

# %%
plt.hist(data['searchability'], bins=20)
# Out:
# (array([3.100e+01, 1.757e+03, 8.640e+02, 3.940e+03, 3.657e+03, 1.555e+03,
#         2.264e+03, 2.004e+03, 9.760e+02, 4.050e+02, 7.000e+02, 3.090e+02,
#         1.440e+02, 1.060e+02, 8.000e+01, 2.100e+01, 1.100e+01, 7.000e+00,
#         4.000e+00, 3.000e+00]),
#  array([0.37048584, 0.40196155, 0.43343726, 0.46491297, 0.49638868,
#         0.52786438, 0.55934009, 0.5908158 , 0.62229151, 0.65376721,
#         0.68524292, 0.71671863, 0.74819434, 0.77967005, 0.81114575,
#         0.84262146, 0.87409717, 0.90557288, 0.93704858, 0.96852429,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.scatter(data['searchability'], data['customer_reviews_count'])

# %%
plt.boxplot(data['searchability'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x71a86d343250>,
#   <matplotlib.lines.Line2D at 0x71a86d3434f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x71a86d343790>,
#   <matplotlib.lines.Line2D at 0x71a86d343a30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x71a86d343100>],
#  'medians': [<matplotlib.lines.Line2D at 0x71a86d343cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x71a86d343f70>],
#  'means': []}

# %%
data = data.dropna()
data['searchability']
# Out:
# 15918    1.000000
# 12864    0.996867
# 17556    0.970137
# 3140     0.966147
# 20893    0.965543
#            ...
# 13715    0.370486
# 8602     0.370486
# 2234     0.370486
# 4096     0.370486
# 12401    0.370486
# Name: searchability, Length: 18838, dtype: float64

# %%
data.to_csv('output.csv', index=False)
